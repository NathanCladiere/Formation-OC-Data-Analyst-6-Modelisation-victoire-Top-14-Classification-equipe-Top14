# %%
import pandas as pd
import datetime
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Importation des données

# %%
xls = pd.ExcelFile('320011_OOA.xls')

# %%
matchstats = xls.parse(0) 
timeline = xls.parse(1) 
ooa = xls.parse(2) 
tackle = xls.parse(3) 
player = xls.parse(4) 
working = xls.parse(5)

# %% [markdown]
# # Mise en forme dataset "mathcstats"

# %%
#selection colonne utile
test = matchstats.loc [:,["Unnamed: 11","Unnamed: 12","Unnamed: 18"]]
#rename pour stat par caté joueurs
test.loc[21,"Unnamed: 12"]= "F5"+"_"+test.loc[21,"Unnamed: 12"]
test.loc[22,"Unnamed: 12"]= "F5"+"_"+test.loc[22,"Unnamed: 12"]
test.loc[23,"Unnamed: 12"]= "F5"+"_"+test.loc[23,"Unnamed: 12"]
test.loc[24,"Unnamed: 12"]= "F5"+"_"+test.loc[24,"Unnamed: 12"]
test.loc[25,"Unnamed: 12"]= "F5"+"_"+test.loc[25,"Unnamed: 12"]
test.loc[26,"Unnamed: 12"]= "F5"+"_"+test.loc[26,"Unnamed: 12"]
test.loc[27,"Unnamed: 12"]= "F5"+"_"+test.loc[27,"Unnamed: 12"]
test.loc[31,"Unnamed: 12"]= "BR"+"_"+test.loc[31,"Unnamed: 12"]
test.loc[32,"Unnamed: 12"]= "BR"+"_"+test.loc[32,"Unnamed: 12"]
test.loc[33,"Unnamed: 12"]= "BR"+"_"+test.loc[33,"Unnamed: 12"]
test.loc[34,"Unnamed: 12"]= "BR"+"_"+test.loc[34,"Unnamed: 12"]
test.loc[35,"Unnamed: 12"]= "BR"+"_"+test.loc[35,"Unnamed: 12"]
test.loc[36,"Unnamed: 12"]= "BR"+"_"+test.loc[36,"Unnamed: 12"]
test.loc[37,"Unnamed: 12"]= "BR"+"_"+test.loc[37,"Unnamed: 12"]
test.loc[41,"Unnamed: 12"]= "B"+"_"+test.loc[41,"Unnamed: 12"]
test.loc[42,"Unnamed: 12"]= "B"+"_"+test.loc[42,"Unnamed: 12"]
test.loc[43,"Unnamed: 12"]= "B"+"_"+test.loc[43,"Unnamed: 12"]
test.loc[44,"Unnamed: 12"]= "B"+"_"+test.loc[44,"Unnamed: 12"]
test.loc[45,"Unnamed: 12"]= "B"+"_"+test.loc[45,"Unnamed: 12"]
test.loc[46,"Unnamed: 12"]= "B"+"_"+test.loc[46,"Unnamed: 12"]
test.loc[47,"Unnamed: 12"]= "B"+"_"+test.loc[47,"Unnamed: 12"]
#drop na et remplacement des na par 0
inter = test.iloc[2:20]
inter2 = test.iloc[21:28]
inter3 = test.iloc[31:38]
inter4 = test.iloc[41:48]
test = pd.concat([inter,inter2,inter3,inter4])
test.fillna(0,inplace = True)

# %%
#conversion en int 
test = test.astype({"Unnamed: 11":int, "Unnamed: 18":int})

# %%
#pivot table pour les variable 
dataMatch = test.pivot_table(values =["Unnamed: 11","Unnamed: 18"],columns =["Unnamed: 12"])
dataMatch["Equipe"]= [matchstats.loc[1,"Unnamed: 11"],matchstats.loc[1,"Unnamed: 18"]]
dataMatch["Match"] = matchstats.loc[1,"Unnamed: 11"]+"-"+matchstats.loc[1,"Unnamed: 18"]
dataMatch["Scrum"] = [matchstats.loc[7,"Unnamed: 52"]+matchstats.loc[8,"Unnamed: 52"],
                          matchstats.loc[7,"Unnamed: 55"]+matchstats.loc[8,"Unnamed: 55"]]
dataMatch["Ratio_Srum"]= [round(matchstats.loc[9,"Unnamed: 52"],2),round(matchstats.loc[9,"Unnamed: 55"],2)]
dataMatch["Ratio_LineOut"]= [round(matchstats.loc[6,"Unnamed: 52"],2),round(matchstats.loc[6,"Unnamed: 55"],2)]
dataMatch["Rucks"] = [matchstats.loc[10,"Unnamed: 52"]+matchstats.loc[12,"Unnamed: 52"],
                          matchstats.loc[10,"Unnamed: 55"]+matchstats.loc[12,"Unnamed: 55"]]
dataMatch["Ratio_Rucks"] = [round(matchstats.loc[13,"Unnamed: 52"],2),round(matchstats.loc[13,"Unnamed: 55"],2)]
dataMatch["time_possession"] = [matchstats.loc[3,"Unnamed: 52"],matchstats.loc[3,"Unnamed: 55"]]
dataMatch["temps_de_jeu_effectifs"] = (datetime.datetime.strptime(str (matchstats.loc[3,"Unnamed: 52"]), '%H:%M:%S')-datetime.datetime.strptime('00:00:00', '%H:%M:%S')+datetime.datetime.strptime(str (matchstats.loc[3,"Unnamed: 55"]), '%H:%M:%S')).time()
dataMatch["Date"] = matchstats.columns[0][-8:]
dataMatch["Points"] = \
[(timeline.loc[6,"Unnamed: 10"]+timeline.loc[6,"Unnamed: 11"])*5+\
(timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"])*3+\
(timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"])*2+\
(timeline.loc[9,"Unnamed: 10"]+timeline.loc[9,"Unnamed: 11"])*3+\
(timeline.loc[11,"Unnamed: 12"]+timeline.loc[11,"Unnamed: 11"])*7,
(timeline.loc[6,"Unnamed: 12"]+timeline.loc[6,"Unnamed: 13"])*5+\
(timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"])*3+\
(timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"])*2+\
(timeline.loc[9,"Unnamed: 12"]+timeline.loc[9,"Unnamed: 13"])*3+\
(timeline.loc[11,"Unnamed: 12"]+timeline.loc[11,"Unnamed: 13"])*7]

if dataMatch.loc["Unnamed: 11","Points"]== dataMatch.loc["Unnamed: 18","Points"]:
    dataMatch["Victoire"] = [0,0]
elif dataMatch.loc["Unnamed: 11","Points"]>dataMatch.loc["Unnamed: 18","Points"]:
    dataMatch["Victoire"] = [1,0]
else:
    dataMatch["Victoire"] = [0,1]
dataMatch["nb participation au ruck off"] = [ooa.loc[29,"Unnamed: 18"],ooa.loc[30,"Unnamed: 18"]]
dataMatch["nb participation au ruck def"] = [ooa.loc[29,"Unnamed: 19"],ooa.loc[30,"Unnamed: 19"]]  
dataMatch["efficacite participant au ruck"] = [round(ooa.loc[29,"Unnamed: 21"],2),round(ooa.loc[30,"Unnamed: 21"],2)]
dataMatch["pen cons dans son camp"] = [working.loc[30,"Unnamed: 1"]+working.loc[30,"Unnamed: 2"]+working.loc[30,"Unnamed: 3"]+working.loc[30,"Unnamed: 4"],
                                       working.loc[31,"Unnamed: 1"]+working.loc[31,"Unnamed: 2"]+working.loc[31,"Unnamed: 3"]+working.loc[31,"Unnamed: 4"]]
dataMatch["domicile"]= [1,0]
dataMatch["ratio transfo"]=[0,0]
if timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"]+\
timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"]+\
timeline.loc[10,"Unnamed: 10"]+timeline.loc[10,"Unnamed: 11"] == 0:
    dataMatch.loc["Unnamed: 11","ratio transfo"]= 0.5
else:
    dataMatch.loc["Unnamed: 11","ratio transfo"]=round((timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"]+\
    timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"])/\
    (timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"]+\
    timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"]+\
    timeline.loc[10,"Unnamed: 10"]+timeline.loc[10,"Unnamed: 11"]),2)

if timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"]+\
    timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"]+\
    timeline.loc[10,"Unnamed: 12"]+timeline.loc[10,"Unnamed: 13"] ==0 :
    dataMatch.loc["Unnamed: 18","ratio transfo"]= 0.5
else:
    dataMatch.loc["Unnamed: 18","ratio transfo"]=round((timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"]+\
    timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"])/\
    (timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"]+\
    timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"]+\
    timeline.loc[10,"Unnamed: 12"]+timeline.loc[10,"Unnamed: 13"]),2)
dataMatch.to_csv("datatemp.csv")
dataMatch= pd.read_csv("datatemp.csv")
dataMatch =dataMatch[[ 'Date','Match','Equipe',"domicile",'Points','Victoire',  'BR_Carries', 'BR_Defenders Beaten', 'BR_Meters', 'BR_Missed Tackles',
       'BR_Offloads', 'BR_Pens Con', 'BR_Tackles', 'B_Carries',
       'B_Defenders Beaten', 'B_Meters', 'B_Missed Tackles', 'B_Offloads',
       'B_Pens Con', 'B_Tackles', 'Carries ', 'Clean Breaks', 'Conversions',
       'Defenders Beaten', 'F5_Carries', 'F5_Defenders Beaten', 'F5_Meters',
       'F5_Missed Tackles', 'F5_Offloads', 'F5_Pens Con', 'F5_Tackles',
       'Kicks In Play', 'Metres', 'Missed Tackles', 'Offloads', 'Passes',
       'Penalty Goal', 'Pens Def', 'Pens Off', 'Tackles', 'Throws Lost',
       'Throws Won', 'Tries', 'Turnovers Con', 'Turnovers Won', 
       'Scrum', 'Ratio_Srum', 'Ratio_LineOut', 'Rucks', 'Ratio_Rucks',
       'time_possession', 'temps_de_jeu_effectifs', 
       'nb participation au ruck off',
       'nb participation au ruck def', 'efficacite participant au ruck',
       'pen cons dans son camp', 'ratio transfo']]
dataMatch.to_csv("dataTop141920.csv")
dataMatch
# Out:
#        Date        Match  Equipe  domicile  Points  Victoire  BR_Carries  \
# 0  24/08/19  Agen-Toulon    Agen         1      25         0          19
# 1  24/08/19  Agen-Toulon  Toulon         0      44         1          15
#
#    BR_Defenders Beaten  BR_Meters  BR_Missed Tackles  BR_Offloads  \
# 0                    1         39                  4            1
# 1                    1         34                  1            0
#
#    BR_Pens Con  BR_Tackles  B_Carries  B_Defenders Beaten  B_Meters  \
# 0            3          27         50                   7       202
# 1            1          19         58                  22       274
#
#    B_Missed Tackles  B_Offloads  B_Pens Con  B_Tackles  Carries   \
# 0                17           4           1         40        83
# 1                 6           5           3         25       103
#
#    Clean Breaks  Conversions  Defenders Beaten  F5_Carries  \
# 0             8            2                11          14
# ...

# %%
verif = False    
if verif == True:
    dataTop141920 = pd.read_csv("dataTop141920.csv")
    dataTop141920 = dataTop141920[[ 'Date','Match','Equipe',"domicile",'Points','Victoire',  'BR_Carries', 'BR_Defenders Beaten', 'BR_Meters', 'BR_Missed Tackles',
               'BR_Offloads', 'BR_Pens Con', 'BR_Tackles', 'B_Carries',
               'B_Defenders Beaten', 'B_Meters', 'B_Missed Tackles', 'B_Offloads',
               'B_Pens Con', 'B_Tackles', 'Carries ', 'Clean Breaks', 'Conversions',
               'Defenders Beaten', 'F5_Carries', 'F5_Defenders Beaten', 'F5_Meters',
               'F5_Missed Tackles', 'F5_Offloads', 'F5_Pens Con', 'F5_Tackles',
               'Kicks In Play', 'Metres', 'Missed Tackles', 'Offloads', 'Passes',
               'Penalty Goal', 'Pens Def', 'Pens Off', 'Tackles', 'Throws Lost',
               'Throws Won', 'Tries', 'Turnovers Con', 'Turnovers Won', 
               'Scrum', 'Ratio_Srum', 'Ratio_LineOut', 'Rucks', 'Ratio_Rucks',
               'time_possession', 'temps_de_jeu_effectifs', 
               'nb participation au ruck off',
               'nb participation au ruck def', 'efficacite participant au ruck',
               'pen cons dans son camp', 'ratio transfo']]
    dataTop141920 = pd.concat([dataTop141920,dataMatch]).drop_duplicates()
    dataTop141920.to_csv("dataTop141920.csv")
    dataTop141920 = pd.read_csv("dataTop141920.csv")

# %%
testDif = False 
if testDif == True :
    testDif =dataTop141920[dataTop141920["Equipe"]=="Bordeaux Begles"][[ 'Date','Match','Equipe',"domicile",'Points','Victoire',  'BR_Carries', 'BR_Defenders Beaten', 'BR_Meters', 'BR_Missed Tackles',
                   'BR_Offloads', 'BR_Pens Con', 'BR_Tackles', 'B_Carries',
                   'B_Defenders Beaten', 'B_Meters', 'B_Missed Tackles', 'B_Offloads',
                   'B_Pens Con', 'B_Tackles', 'Carries ', 'Clean Breaks', 'Conversions',
                   'Defenders Beaten', 'F5_Carries', 'F5_Defenders Beaten', 'F5_Meters',
                   'F5_Missed Tackles', 'F5_Offloads', 'F5_Pens Con', 'F5_Tackles',
                   'Kicks In Play', 'Metres', 'Missed Tackles', 'Offloads', 'Passes',
                   'Penalty Goal', 'Pens Def', 'Pens Off', 'Tackles', 'Throws Lost',
                   'Throws Won', 'Tries', 'Turnovers Con', 'Turnovers Won', 
                   'Scrum', 'Ratio_Srum', 'Ratio_LineOut', 'Rucks', 'Ratio_Rucks',
                   'time_possession', 'temps_de_jeu_effectifs', 
                   'nb participation au ruck off',
                   'nb participation au ruck def', 'efficacite participant au ruck',
                   'pen cons dans son camp', 'ratio transfo']]
    testDif[testDif.columns[testDif.iloc[0] != testDif.iloc[1]]]
    print(testDif.loc[2,"Ratio_Rucks"])
    print(testDif.loc[4,"Ratio_Rucks"])

# %%
niceTry = True
if niceTry == True:
    listMatch =['320011_OOA.xls','320012_OOA.xls','320013_OOA.xls',
                '320014_OOA.xls','320015_OOA.xls','320016_OOA.xls','320017_OOA.xls',
    '320021_OOA.xls',    '320022_OOA.xls',    '320023_OOA.xls',    '320024_OOA.xls',
    '320025_OOA.xls',    '320026_OOA.xls',    '320027_OOA.xls',    '320031_OOA.xls',
    '320032_OOA.xls',    '320033_OOA.xls',    '320034_OOA.xls',    '320035_OOA.xls',
    '320036_OOA.xls',    '320037_OOA.xls',    '320041_OOA.xls',    '320042_OOA.xls',
    '320043_OOA.xls',    '320044_OOA.xls',    '320045_OOA.xls',    '320046_OOA.xls',
    '320047_OOA.xls',    '320051_OOA.xls',    '320052_OOA.xls',    '320053_OOA.xls',
    '320054_OOA.xls',    '320055_OOA.xls',    '320056_OOA.xls',    '320057_OOA.xls',
    '320061_OOA.xls',    '320062_OOA.xls',    '320063_OOA.xls',    '320064_OOA.xls',
    '320065_OOA.xls',    '320066_OOA.xls',    '320067_OOA.xls',    '320071_OOA.xls',
    '320072_OOA.xls',    '320073_OOA.xls',    '320074_OOA.xls',    '320075_OOA.xls',
    '320076_OOA.xls',    '320077_OOA.xls',    '320081_OOA.xls',    '320082_OOA.xls',
    '320083_OOA.xls',    '320084_OOA.xls',    '320085_OOA.xls',    '320086_OOA.xls',
    '320087_OOA.xls',    '320091_OOA.xls',    '320092_OOA.xls',    '320093_OOA.xls',
    '320094_OOA.xls',    '320095_OOA.xls',    '320096_OOA.xls',    '320097_OOA.xls',
    '320101_OOA.xls',    '320102_OOA.xls',    '320103_OOA.xls',    '320104_OOA.xls',
    '320105_OOA.xls',    '320106_OOA.xls',    '320107_OOA.xls',    '320111_OOA.xls',
    '320112_OOA.xls',    '320113_OOA.xls',    '320114_OOA.xls',    '320115_OOA.xls',
    '320116_OOA.xls',    '320117_OOA.xls',    '320121_OOA.xls',    '320122_OOA.xls',
    '320123_OOA.xls',    '320124_OOA.xls',    '320125_OOA.xls',    '320126_OOA.xls',
    '320127_OOA.xls',    '320131_OOA.xls',    '320132_OOA.xls',    '320133_OOA.xls',
    '320134_OOA.xls',    '320135_OOA.xls',    '320136_OOA.xls',    '320137_OOA.xls',
    '320141_OOA.xls',    '320142_OOA.xls',    '320143_OOA.xls',    '320144_OOA.xls',
    '320145_OOA.xls',    '320146_OOA.xls',    '320147_OOA.xls',    '320151_OOA.xls',
    '320152_OOA.xls',    '320153_OOA.xls',    '320154_OOA.xls',    '320155_OOA.xls',
    '320156_OOA.xls',    '320157_OOA.xls',    '320161_OOA.xls',    '320162_OOA.xls',
    '320163_OOA.xls',    '320164_OOA.xls',    '320165_OOA.xls',    '320166_OOA.xls',
    '320167_OOA.xls',    '320171_OOA.xls',    '320172_OOA.xls',    '320173_OOA.xls',
    '320174_OOA.xls',    '320175_OOA.xls',    '320176_OOA.xls',    '320177_OOA.xls']
    for i in listMatch:
        name= str(i)
        xls = pd.ExcelFile(name)
        matchstats = xls.parse(0) 
        timeline = xls.parse(1) 
        ooa = xls.parse(2) 
        tackle = xls.parse(3) 
        player = xls.parse(4) 
        working = xls.parse(5)
        #selection colonne utile
        test = matchstats.loc [:,["Unnamed: 11","Unnamed: 12","Unnamed: 18"]]
        #rename pour stat par caté joueurs
        test.loc[21,"Unnamed: 12"]= "F5"+"_"+test.loc[21,"Unnamed: 12"]
        test.loc[22,"Unnamed: 12"]= "F5"+"_"+test.loc[22,"Unnamed: 12"]
        test.loc[23,"Unnamed: 12"]= "F5"+"_"+test.loc[23,"Unnamed: 12"]
        test.loc[24,"Unnamed: 12"]= "F5"+"_"+test.loc[24,"Unnamed: 12"]
        test.loc[25,"Unnamed: 12"]= "F5"+"_"+test.loc[25,"Unnamed: 12"]
        test.loc[26,"Unnamed: 12"]= "F5"+"_"+test.loc[26,"Unnamed: 12"]
        test.loc[27,"Unnamed: 12"]= "F5"+"_"+test.loc[27,"Unnamed: 12"]
        test.loc[31,"Unnamed: 12"]= "BR"+"_"+test.loc[31,"Unnamed: 12"]
        test.loc[32,"Unnamed: 12"]= "BR"+"_"+test.loc[32,"Unnamed: 12"]
        test.loc[33,"Unnamed: 12"]= "BR"+"_"+test.loc[33,"Unnamed: 12"]
        test.loc[34,"Unnamed: 12"]= "BR"+"_"+test.loc[34,"Unnamed: 12"]
        test.loc[35,"Unnamed: 12"]= "BR"+"_"+test.loc[35,"Unnamed: 12"]
        test.loc[36,"Unnamed: 12"]= "BR"+"_"+test.loc[36,"Unnamed: 12"]
        test.loc[37,"Unnamed: 12"]= "BR"+"_"+test.loc[37,"Unnamed: 12"]
        test.loc[41,"Unnamed: 12"]= "B"+"_"+test.loc[41,"Unnamed: 12"]
        test.loc[42,"Unnamed: 12"]= "B"+"_"+test.loc[42,"Unnamed: 12"]
        test.loc[43,"Unnamed: 12"]= "B"+"_"+test.loc[43,"Unnamed: 12"]
        test.loc[44,"Unnamed: 12"]= "B"+"_"+test.loc[44,"Unnamed: 12"]
        test.loc[45,"Unnamed: 12"]= "B"+"_"+test.loc[45,"Unnamed: 12"]
        test.loc[46,"Unnamed: 12"]= "B"+"_"+test.loc[46,"Unnamed: 12"]
        test.loc[47,"Unnamed: 12"]= "B"+"_"+test.loc[47,"Unnamed: 12"]
        #drop na et remplacement des na par 0
        inter = test.iloc[2:20]
        inter2 = test.iloc[21:28]
        inter3 = test.iloc[31:38]
        inter4 = test.iloc[41:48]
        test = pd.concat([inter,inter2,inter3,inter4])
        test.fillna(0,inplace = True)
        #conversion en int 
        test = test.astype({"Unnamed: 11":int, "Unnamed: 18":int})
        #pivot table pour les variable 
        dataMatch = test.pivot_table(values =["Unnamed: 11","Unnamed: 18"],columns =["Unnamed: 12"])
        dataMatch["Equipe"]= [matchstats.loc[1,"Unnamed: 11"],matchstats.loc[1,"Unnamed: 18"]]
        dataMatch["Match"] = matchstats.loc[1,"Unnamed: 11"]+"-"+matchstats.loc[1,"Unnamed: 18"]
        dataMatch["Scrum"] = [matchstats.loc[7,"Unnamed: 52"]+matchstats.loc[8,"Unnamed: 52"],
                                  matchstats.loc[7,"Unnamed: 55"]+matchstats.loc[8,"Unnamed: 55"]]
        dataMatch["Ratio_Srum"]=[round(matchstats.loc[9,"Unnamed: 52"],2),round(matchstats.loc[9,"Unnamed: 55"],2)]
        dataMatch["Ratio_LineOut"]=[round(matchstats.loc[6,"Unnamed: 52"],2),round(matchstats.loc[6,"Unnamed: 55"],2)]
        dataMatch["Rucks"] = [matchstats.loc[10,"Unnamed: 52"]+matchstats.loc[12,"Unnamed: 52"],
                                  matchstats.loc[10,"Unnamed: 55"]+matchstats.loc[12,"Unnamed: 55"]]
        dataMatch["Ratio_Rucks"] = [round(matchstats.loc[13,"Unnamed: 52"],2),round(matchstats.loc[13,"Unnamed: 55"],2)]
        dataMatch["time_possession"] = [matchstats.loc[3,"Unnamed: 52"],matchstats.loc[3,"Unnamed: 55"]]
        dataMatch["temps_de_jeu_effectifs"] = (datetime.datetime.strptime(str (matchstats.loc[3,"Unnamed: 52"]), '%H:%M:%S')-datetime.datetime.strptime('00:00:00', '%H:%M:%S')+datetime.datetime.strptime(str (matchstats.loc[3,"Unnamed: 55"]), '%H:%M:%S')).time()
        dataMatch["Date"] = matchstats.columns[0][-8:]
        dataMatch["Points"] = \
        [(timeline.loc[6,"Unnamed: 10"]+timeline.loc[6,"Unnamed: 11"])*5+\
        (timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"])*3+\
        (timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"])*2+\
        (timeline.loc[9,"Unnamed: 10"]+timeline.loc[9,"Unnamed: 11"])*3+\
        (timeline.loc[11,"Unnamed: 12"]+timeline.loc[11,"Unnamed: 11"])*7,
        (timeline.loc[6,"Unnamed: 12"]+timeline.loc[6,"Unnamed: 13"])*5+\
        (timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"])*3+\
        (timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"])*2+\
        (timeline.loc[9,"Unnamed: 12"]+timeline.loc[9,"Unnamed: 13"])*3+\
        (timeline.loc[11,"Unnamed: 12"]+timeline.loc[11,"Unnamed: 13"])*7]

        if dataMatch.loc["Unnamed: 11","Points"]== dataMatch.loc["Unnamed: 18","Points"]:
            dataMatch["Victoire"] = [0,0]
        elif dataMatch.loc["Unnamed: 11","Points"]>dataMatch.loc["Unnamed: 18","Points"]:
            dataMatch["Victoire"] = [1,0]
        else:
            dataMatch["Victoire"] = [0,1]
        dataMatch["nb participation au ruck off"] = [ooa.loc[29,"Unnamed: 18"],ooa.loc[30,"Unnamed: 18"]]
        dataMatch["nb participation au ruck def"] = [ooa.loc[29,"Unnamed: 19"],ooa.loc[30,"Unnamed: 19"]]  
        dataMatch["efficacite participant au ruck"] = [round(ooa.loc[29,"Unnamed: 21"],2),round(ooa.loc[30,"Unnamed: 21"],2)]
        dataMatch["pen cons dans son camp"] = [working.loc[30,"Unnamed: 1"]+working.loc[30,"Unnamed: 2"]+working.loc[30,"Unnamed: 3"]+working.loc[30,"Unnamed: 4"],
                                               working.loc[31,"Unnamed: 1"]+working.loc[31,"Unnamed: 2"]+working.loc[31,"Unnamed: 3"]+working.loc[31,"Unnamed: 4"]]
        dataMatch["domicile"]= [1,0]
        dataMatch["ratio transfo"]=[0,0]
        if timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"]+\
        timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"]+\
        timeline.loc[10,"Unnamed: 10"]+timeline.loc[10,"Unnamed: 11"] == 0:
            dataMatch.loc["Unnamed: 11","ratio transfo"]= 0.5
        else:
            dataMatch.loc["Unnamed: 11","ratio transfo"]=round((timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"]+\
            timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"])/\
            (timeline.loc[7,"Unnamed: 10"]+timeline.loc[7,"Unnamed: 11"]+\
            timeline.loc[8,"Unnamed: 10"]+timeline.loc[8,"Unnamed: 11"]+\
            timeline.loc[10,"Unnamed: 10"]+timeline.loc[10,"Unnamed: 11"]),2)

        if timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"]+\
            timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"]+\
            timeline.loc[10,"Unnamed: 12"]+timeline.loc[10,"Unnamed: 13"] ==0 :
            dataMatch.loc["Unnamed: 18","ratio transfo"]= 0.5
        else:
            dataMatch.loc["Unnamed: 18","ratio transfo"]=round((timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"]+\
            timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"])/\
            (timeline.loc[7,"Unnamed: 12"]+timeline.loc[7,"Unnamed: 13"]+\
            timeline.loc[8,"Unnamed: 12"]+timeline.loc[8,"Unnamed: 13"]+\
            timeline.loc[10,"Unnamed: 12"]+timeline.loc[10,"Unnamed: 13"]),2)
        dataMatch.to_csv("datatemp.csv")
        dataMatch= pd.read_csv("datatemp.csv")
        dataMatch =dataMatch[[ 'Date','Match','Equipe',"domicile",'Points','Victoire',  'BR_Carries', 'BR_Defenders Beaten', 'BR_Meters', 'BR_Missed Tackles',
               'BR_Offloads', 'BR_Pens Con', 'BR_Tackles', 'B_Carries',
               'B_Defenders Beaten', 'B_Meters', 'B_Missed Tackles', 'B_Offloads',
               'B_Pens Con', 'B_Tackles', 'Carries ', 'Clean Breaks', 'Conversions',
               'Defenders Beaten', 'F5_Carries', 'F5_Defenders Beaten', 'F5_Meters',
               'F5_Missed Tackles', 'F5_Offloads', 'F5_Pens Con', 'F5_Tackles',
               'Kicks In Play', 'Metres', 'Missed Tackles', 'Offloads', 'Passes',
               'Penalty Goal', 'Pens Def', 'Pens Off', 'Tackles', 'Throws Lost',
               'Throws Won', 'Tries', 'Turnovers Con', 'Turnovers Won', 
               'Scrum', 'Ratio_Srum', 'Ratio_LineOut', 'Rucks', 'Ratio_Rucks',
               'time_possession', 'temps_de_jeu_effectifs', 
               'nb participation au ruck off',
               'nb participation au ruck def', 'efficacite participant au ruck',
               'pen cons dans son camp', 'ratio transfo']]
        dataTop141920 = pd.read_csv("dataTop141920.csv")
        dataTop141920 = dataTop141920[[ 'Date','Match','Equipe',"domicile",'Points','Victoire',  'BR_Carries', 'BR_Defenders Beaten', 'BR_Meters', 'BR_Missed Tackles',
               'BR_Offloads', 'BR_Pens Con', 'BR_Tackles', 'B_Carries',
               'B_Defenders Beaten', 'B_Meters', 'B_Missed Tackles', 'B_Offloads',
               'B_Pens Con', 'B_Tackles', 'Carries ', 'Clean Breaks', 'Conversions',
               'Defenders Beaten', 'F5_Carries', 'F5_Defenders Beaten', 'F5_Meters',
               'F5_Missed Tackles', 'F5_Offloads', 'F5_Pens Con', 'F5_Tackles',
               'Kicks In Play', 'Metres', 'Missed Tackles', 'Offloads', 'Passes',
               'Penalty Goal', 'Pens Def', 'Pens Off', 'Tackles', 'Throws Lost',
               'Throws Won', 'Tries', 'Turnovers Con', 'Turnovers Won', 
               'Scrum', 'Ratio_Srum', 'Ratio_LineOut', 'Rucks', 'Ratio_Rucks',
               'time_possession', 'temps_de_jeu_effectifs', 
               'nb participation au ruck off',
               'nb participation au ruck def', 'efficacite participant au ruck',
               'pen cons dans son camp', 'ratio transfo']]
        dataTop141920 = pd.concat([dataTop141920,dataMatch]).drop_duplicates()
        dataTop141920.to_csv("dataTop141920.csv")

# %%
dataTop141920 = pd.read_csv("dataTop141920.csv")
dataTop141920
# Out:
#      Unnamed: 0      Date                              Match  \
# 0             0  24/08/19                        Agen-Toulon
# 1             1  24/08/19                        Agen-Toulon
# 2             2  24/08/19           Bordeaux Begles-Toulouse
# 3             3  24/08/19           Bordeaux Begles-Toulouse
# 4             4  24/08/19                Castres-Montpellier
# 5             5  24/08/19                Castres-Montpellier
# 6             6  25/08/19      Clermont Auvergne-La Rochelle
# 7             7  25/08/19      Clermont Auvergne-La Rochelle
# 8             8  24/08/19                Lyon-Stade Francais
# 9             9  24/08/19                Lyon-Stade Francais
# 10           10  24/08/19                          Pau-Brive
# 11           11  24/08/19                          Pau-Brive
# 12           12  24/08/19                  Racing 92-Bayonne
# 13           13  24/08/19                  Racing 92-Bayonne
# ...

# %%
dataTop141920.shape
# Out:
# (238, 58)

# %%
238/2
# Out:
# 119.0

# %%
17*7
# Out:
# 119
